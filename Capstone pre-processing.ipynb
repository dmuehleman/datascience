# %%
import pandas as pd
import numpy as np

# %%
cpdata = pd.read_csv(r'C:\Users\langa\OneDrive\Documents\Data Analytics Class\Capstone\student-mat2.csv')

# %%
cpdata.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
cpdata.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
cpdata = cpdata.drop_duplicates()

# %%
cpdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
school_cond = [cpdata['school'] == 'GP', cpdata['school'] == 'MS']
school_choices = [1,2]
cpdata['school'] = np.select(school_cond, school_choices)

# %%
sex_cond = [cpdata['sex'] == 'M', cpdata['sex'] == 'F']
sex_choices = [1,2]
cpdata['sex'] = np.select(sex_cond, sex_choices)

# %%
address_cond = [cpdata['address'] == 'U', cpdata['address'] == 'R']
address_choices = [1,2]
cpdata['address'] = np.select(address_cond, address_choices)

# %%
famsize_cond = [cpdata['famsize'] == 'LE3', cpdata['famsize'] == 'GT3']
famsize_choices = [1,2]
cpdata['famsize'] = np.select(famsize_cond, famsize_choices)

# %%
Pstatus_cond = [cpdata['Pstatus'] == 'T', cpdata['Pstatus'] == 'A']
Pstatus_choices = [1,2]
cpdata['Pstatus'] = np.select(Pstatus_cond, Pstatus_choices)

# %%
Mjob_cond = [cpdata['Mjob'] == 'teacher', cpdata['Mjob'] == 'health', cpdata['Mjob'] == 'services', 
             cpdata['Mjob'] == 'at_home', cpdata['Mjob'] == 'other']
Mjob_choices = [0,1,2,3,4]
cpdata['Mjob'] = np.select(Mjob_cond, Mjob_choices)

# %%
Fjob_cond = [cpdata['Fjob'] == 'teacher', cpdata['Fjob'] == 'health', cpdata['Fjob'] == 'services', 
             cpdata['Fjob'] == 'at_home', cpdata['Fjob'] == 'other']
Fjob_choices = [0,1,2,3,4]
cpdata['Fjob'] = np.select(Fjob_cond, Fjob_choices)

# %%
reason_cond = [cpdata['reason'] == 'home', cpdata['reason'] == 'reputation', cpdata['reason'] == 'course', 
             cpdata['reason'] == 'other']
reason_choices = [0,1,2,3]
cpdata['reason'] = np.select(reason_cond, reason_choices)

# %%
guardian_cond = [cpdata['guardian'] == 'mother', cpdata['guardian'] == 'father', cpdata['guardian'] == 'other']
guardian_choices = [1,2,3]
cpdata['guardian'] = np.select(guardian_cond, guardian_choices)

# %%
schoolsup_cond = [cpdata['schoolsup'] == 'yes', cpdata['schoolsup'] == 'no']
schoolsup_choices = [1,2]
cpdata['schoolsup'] = np.select(schoolsup_cond, schoolsup_choices)

# %%
famsup_cond = [cpdata['famsup'] == 'yes', cpdata['famsup'] == 'no']
famsup_choices = [1,2]
cpdata['famsup'] = np.select(famsup_cond, famsup_choices)

# %%
paid_cond = [cpdata['paid'] == 'yes', cpdata['paid'] == 'no']
paid_choices = [1,2]
cpdata['paid'] = np.select(paid_cond, paid_choices)

# %%
activities_cond = [cpdata['activities'] == 'yes', cpdata['activities'] == 'no']
activities_choices = [1,2]
cpdata['activities'] = np.select(activities_cond, activities_choices)

# %%
nursery_cond = [cpdata['nursery'] == 'yes', cpdata['nursery'] == 'no']
nursery_choices = [1,2]
cpdata['nursery'] = np.select(nursery_cond, nursery_choices)

# %%
higher_cond = [cpdata['higher'] == 'yes', cpdata['higher'] == 'no']
higher_choices = [1,2]
cpdata['higher'] = np.select(higher_cond, higher_choices)

# %%
internet_cond = [cpdata['internet'] == 'yes', cpdata['internet'] == 'no']
internet_choices = [1,2]
cpdata['internet'] = np.select(internet_cond, internet_choices)

# %%
romantic_cond = [cpdata['romantic'] == 'yes', cpdata['romantic'] == 'no']
romantic_choices = [1,2]
cpdata['romantic'] = np.select(romantic_cond, romantic_choices)

# %%
cpdata.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       1    2   18        1        2        2     4     4     3     0  ...
# 1       1    2   17        1        2        1     1     1     3     4  ...
# 2       1    2   15        1        1        1     1     1     3     4  ...
# 3       1    2   15        1        2        1     4     2     1     2  ...
# 4       1    2   16        1        2        1     3     3     4     4  ...
#
#    famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0       4         3      4     1     1       3         6   5   6   6
# 1       5         3      3     1     1       3         4   5   5   6
# 2       4         3      2     2     3       3        10   7   8  10
# 3       3         2      2     1     1       5         2  15  14  15
# 4       4         3      2     1     2       5         4   6  10  10
#
# [5 rows x 33 columns]

# %%
cpdata.to_csv('cpdata2.csv')

# %%
cpdata2 = pd.read_csv(r'C:\Users\langa\OneDrive\Documents\Data Analytics Class\Capstone\cpdata2.csv')

# %%
cpdata2.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       1    2   18        1        2        2     4     4     3     0  ...
# 1       1    2   17        1        2        1     1     1     3     4  ...
# 2       1    2   15        1        1        1     1     1     3     4  ...
# 3       1    2   15        1        2        1     4     2     1     2  ...
# 4       1    2   16        1        2        1     3     3     4     4  ...
#
#    famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0       4         3      4     1     1       3         6   5   6   6
# 1       5         3      3     1     1       3         4   5   5   6
# 2       4         3      2     2     3       3        10   7   8  10
# 3       3         2      2     1     1       5         2  15  14  15
# 4       4         3      2     1     2       5         4   6  10  10
#
# [5 rows x 33 columns]
